# %% [markdown]
# <a href="https://colab.research.google.com/github/vishal-gaddam/mercedes-benz-python-interview/blob/main/Python_Interview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 1. Find the maximum of sum of three consecutive rows?

# %%
matrix = np.loadtxt("sample_numbers.txt", dtype=int)

print("Dim", np.shape(matrix))
print("Data: \n", matrix)

# %%
## Your code here
matrix = np.random.randint(100, 999, (10, 10))
matrix
# Out:
# array([[490, 463, 335, 259, 664, 970, 550, 661, 300, 365],
#        [236, 650, 820, 353, 114, 120, 859, 472, 592, 482],
#        [480, 709, 456, 775, 353, 567, 929, 809, 409, 601],
#        [493, 728, 649, 733, 514, 545, 616, 686, 641, 305],
#        [822, 181, 689, 822, 630, 451, 707, 234, 198, 648],
#        [402, 308, 580, 136, 979, 110, 289, 182, 411, 299],
#        [531, 422, 248, 601, 652, 985, 506, 149, 953, 697],
#        [765, 916, 530, 209, 405, 586, 597, 414, 412, 889],
#        [334, 112, 585, 786, 277, 630, 790, 370, 116, 407],
#        [412, 884, 466, 641, 899, 221, 312, 295, 349, 110]])

# %%
## Your code here.

# %% [markdown]
# # 2. Recursive function
# Evaluate the activity of the recursive function?

# %%
def recursive_function(number:int):
  if number <= 1:
    pass
  elif number % 2 == 0:
    return recursive_function(int(number * 2 / 3))
  else:
    return recursive_function(number // 2)

recursive_function(13)

# %% [markdown]
# # 3. Strange Function
# Evaluate the activity of the strange_function?

# %%
def strange_function(number:int, nr_count:int = 1):
  if number <= 1:
    return nr_count
  elif number % 2 == 0:
    return strange_function(int(number * 2 / 3), nr_count + 1)
  else:
    return strange_function(number // 2, nr_count + 1)


strange_function(2278952)

# %% [markdown]
# # 4. Slow as a snail

# %%
max([strange_function(x) for x in range(187923)])

# %% [markdown]
# # 5. Packaging Techniques

# %% [markdown]
# ![packaging.jpg](data:image/jpeg;base64,...)

# %%
## Your code here.
